# %%
from numpy import loadtxt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Normalization

# %%
# load the dataset
dataset = loadtxt('pima-indians-diabetes.csv', delimiter=',')

# split into input (X) and output (y) variables
X = dataset[:, 0:8]
y = dataset[:, 8]

# %%
# normalize the input data
normalizer = Normalization(axis=-1)
normalizer.adapt(X)
X = normalizer(X)

# %%
# define the keras model
model = Sequential()
model.add(Dense(64, input_shape=(8,), activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model using the original dataset as validation
history = model.fit(X, y, epochs=120, batch_size=16, verbose=0)

# %%
# evaluate the keras model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy * 100))
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9902 - loss: 0.0443
# Accuracy: 98.83

# %%
# make class predictions with the model  
predictions = (model.predict(X) > 0.5).astype(int)
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step

# %%
# summarize the first 5 cases
for i in range(5):
    print('%s => %d (expected %d)' % ([round(num, 1) for num in X[i].numpy().tolist()], predictions[i], y[i]))
# Out:
# [0.6, 0.8, 0.1, 0.9, -0.7, 0.2, 0.5, 1.4] => 1 (expected 1)
# [-0.8, -1.1, -0.2, 0.5, -0.7, -0.7, -0.4, -0.2] => 0 (expected 0)
# [1.2, 1.9, -0.3, -1.3, -0.7, -1.1, 0.6, -0.1] => 1 (expected 1)
# [-0.8, -1.0, -0.2, 0.2, 0.1, -0.5, -0.9, -1.0] => 0 (expected 0)
# [-1.1, 0.5, -1.5, 0.9, 0.8, 1.4, 5.5, -0.0] => 1 (expected 1)
# C:\Users\escan\AppData\Local\Temp\ipykernel_26076\1598492428.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print('%s => %d (expected %d)' % ([round(num, 1) for num in X[i].numpy().tolist()], predictions[i], y[i]))
